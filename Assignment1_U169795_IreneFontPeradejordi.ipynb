# %% [markdown]
# ANR: ....

# %%
# %matplotlib inline

# %%
import warnings

# %%
import pandas as pd

# %%
df = pd.DataFrame.from_csv('/srv/data-mining/data/Titanic/titanic.csv',index_col='PassengerId')

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %%
df.count(axis=0,level=None, numeric_only=False)
# Out:
# Survived    891
# Pclass      891
# Name        891
# Sex         891
# Age         714
# SibSp       891
# Parch       891
# Ticket      891
# Fare        891
# Cabin       204
# Embarked    889
# dtype: int64

# %%
df.count(axis=1)
# Out:
# PassengerId
# 1      10
# 2      11
# 3      10
# 4      11
# 5      10
# 6       9
# 7      11
# 8      10
# 9      10
# 10     10
# 11     11
# 12     11
# 13     10
# 14     10
# 15     10
# 16     10
# 17     10
# 18      9
# 19     10
# 20      9
# 21     10
# 22     11
# 23     10
# 24     11
# 25     10
# 26     10
# 27      9
# 28     11
# 29      9
# 30      9
#        ..
# 862    10
# 863    11
# 864     9
# 865    10
# 866    10
# 867    10
# 868    11
# 869     9
# 870    10
# 871    10
# 872    11
# 873    11
# 874    10
# 875    10
# 876    10
# 877    10
# 878    10
# 879     9
# 880    11
# 881    10
# 882    10
# 883    10
# 884    10
# 885    10
# 886    10
# 887    10
# 888    11
# 889     9
# 890    11
# 891    10
# dtype: int64

# %%
df['Fare']
# Out:
# PassengerId
# 1        7.2500
# 2       71.2833
# 3        7.9250
# 4       53.1000
# 5        8.0500
# 6        8.4583
# 7       51.8625
# 8       21.0750
# 9       11.1333
# 10      30.0708
# 11      16.7000
# 12      26.5500
# 13       8.0500
# 14      31.2750
# 15       7.8542
# 16      16.0000
# 17      29.1250
# 18      13.0000
# 19      18.0000
# 20       7.2250
# 21      26.0000
# 22      13.0000
# 23       8.0292
# 24      35.5000
# 25      21.0750
# 26      31.3875
# 27       7.2250
# 28     263.0000
# 29       7.8792
# 30       7.8958
#          ...
# 862     11.5000
# 863     25.9292
# 864     69.5500
# 865     13.0000
# 866     13.0000
# 867     13.8583
# 868     50.4958
# 869      9.5000
# 870     11.1333
# 871      7.8958
# 872     52.5542
# 873      5.0000
# 874      9.0000
# 875     24.0000
# 876      7.2250
# 877      9.8458
# 878      7.8958
# 879      7.8958
# 880     83.1583
# 881     26.0000
# 882      7.8958
# 883     10.5167
# 884     10.5000
# ...

# %%
df[['Name', 'Fare']]
# Out:
#                                                           Name      Fare
# PassengerId
# 1                                      Braund, Mr. Owen Harris    7.2500
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...   71.2833
# 3                                       Heikkinen, Miss. Laina    7.9250
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)   53.1000
# 5                                     Allen, Mr. William Henry    8.0500
# 6                                             Moran, Mr. James    8.4583
# 7                                      McCarthy, Mr. Timothy J   51.8625
# 8                               Palsson, Master. Gosta Leonard   21.0750
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)   11.1333
# 10                         Nasser, Mrs. Nicholas (Adele Achem)   30.0708
# 11                             Sandstrom, Miss. Marguerite Rut   16.7000
# 12                                    Bonnell, Miss. Elizabeth   26.5500
# ...

# %%
df[['Age', 'Name', 'Fare']]
# Out:
#               Age                                               Name      Fare
# PassengerId
# 1            22.0                            Braund, Mr. Owen Harris    7.2500
# 2            38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...   71.2833
# 3            26.0                             Heikkinen, Miss. Laina    7.9250
# 4            35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)   53.1000
# 5            35.0                           Allen, Mr. William Henry    8.0500
# 6             NaN                                   Moran, Mr. James    8.4583
# 7            54.0                            McCarthy, Mr. Timothy J   51.8625
# 8             2.0                     Palsson, Master. Gosta Leonard   21.0750
# 9            27.0  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)   11.1333
# 10           14.0                Nasser, Mrs. Nicholas (Adele Achem)   30.0708
# 11            4.0                    Sandstrom, Miss. Marguerite Rut   16.7000
# ...

# %%
df['Pclass']
# Out:
# PassengerId
# 1      3
# 2      1
# 3      3
# 4      1
# 5      3
# 6      3
# 7      1
# 8      3
# 9      3
# 10     2
# 11     3
# 12     1
# 13     3
# 14     3
# 15     3
# 16     2
# 17     3
# 18     2
# 19     3
# 20     3
# 21     2
# 22     2
# 23     3
# 24     1
# 25     3
# 26     3
# 27     3
# 28     1
# 29     3
# 30     3
#       ..
# 862    2
# 863    1
# 864    3
# 865    2
# 866    2
# 867    2
# 868    1
# 869    3
# 870    3
# 871    3
# 872    1
# 873    1
# 874    3
# 875    2
# 876    3
# 877    3
# 878    3
# 879    3
# 880    1
# 881    2
# 882    3
# 883    3
# 884    2
# 885    3
# 886    3
# 887    2
# 888    1
# 889    3
# 890    1
# 891    3
# Name: Pclass, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df.groupby('Sex')['Pclass'].value_counts()
# Out:
# Sex     Pclass
# female  3         144
#         1          94
#         2          76
# male    3         347
#         1         122
#         2         108
# Name: Pclass, dtype: int64

# %%
df.groupby('Sex')['Pclass'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Pclass, dtype: int64

# %%
df.groupby('Sex').count()
# Out:
#         Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  Cabin  \
# Sex
# female       314     314   314  261    314    314     314   314     97
# male         577     577   577  453    577    577     577   577    107
#
#         Embarked
# Sex
# female       312
# male         577

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# # Visualization

# %%
df.groupby('Survived')['Fare'].value_counts()
# Out:
# Survived  Fare
# 0         8.0500      38
#           7.8958      37
#           13.0000     26
#           7.7500      22
#           26.0000     16
#           10.5000     15
#           0.0000      14
#           7.7750      13
#           7.2500      12
#           8.6625      12
#           7.2292      11
#           7.8542      10
#           7.9250      10
#           7.2250       9
#           7.0500       7
#           9.5000       7
#           16.1000      7
#           24.1500      7
#           26.5500      7
#           31.2750      7
#           69.5500      7
#           14.4542      6
#           27.9000      6
#           39.6875      6
#           46.9000      6
#           14.5000      5
#           15.5000      5
#           29.1250      5
#           73.5000      5
#           7.1250       4
#                       ..
# 1         26.3875      1
#           27.0000      1
#           27.7208      1
#           29.7000      1
#           30.0708      1
# ...

# %%
df.groupby('Survived')['Fare'].plot(kind='kde', legend=True)
# Out:
# Survived
# 0    Axes(0.125,0.125;0.775x0.755)
# 1    Axes(0.125,0.125;0.775x0.755)
# Name: Fare, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
df.groupby('Survived')['Fare'].plot(kind='kde')
# Out:
# Survived
# 0    Axes(0.125,0.125;0.775x0.755)
# 1    Axes(0.125,0.125;0.775x0.755)
# Name: Fare, dtype: object

# %%
df.groupby('Survived')['Sex'].value_counts()
# Out:
# Survived  Sex
# 0         male      468
#           female     81
# 1         female    233
#           male      109
# Name: Sex, dtype: int64

# %%
df.groupby('Survived')['Sex'].value_counts().plot(kind='Bar')

# %%
df['Age'] = df['Age'].fillna(0)

# %%
df.groupby('Age')['Survived'].value_counts()
# Out:
# Age    Survived
# 0.00   0           125
#        1            52
# 0.42   1             1
# 0.67   1             1
# 0.75   1             2
# 0.83   1             2
# 0.92   1             1
# 1.00   1             5
#        0             2
# 2.00   0             7
#        1             3
# 3.00   1             5
#        0             1
# 4.00   1             7
#        0             3
# 5.00   1             4
# 6.00   1             2
#        0             1
# 7.00   0             2
#        1             1
# 8.00   0             2
#        1             2
# 9.00   0             6
#        1             2
# 10.00  0             2
# 11.00  0             3
#        1             1
# 12.00  1             1
# 13.00  1             2
# 14.00  0             3
#                   ...
# 51.00  0             5
#        1             2
# 52.00  0             3
#        1             3
# 53.00  1             1
# 54.00  0             5
#        1             3
# 55.00  0             1
# ...

# %%
df.groupby('Survived')['Age'].value_counts().plot(kind='Bar')

# %%
df.groupby(['Sex', 'Pclass'])['Survived'].value_counts().plot(kind='Bar')

# %%
df.groupby(['Sex', 'Pclass'])['Survived'].mean().plot(kind='Bar')

# %%
df.groupby('Sex')['Survived'].value_counts().plot(kind='Bar') #male died more than female

# %%
df.groupby('Fare')['Survived'].value_counts().plot(kind='Bar')

# %%
df.groupby('Survived')['Fare'].value_counts().plot(kind='Bar')

# %%
df.plot(x='Age', y='Fare', kind='scatter')

# %%
died_subset = df[df['Survived'] == 0]
live_subset = df[df['Survived'] != 0]

# %%
ax1 = died_subset.plot(x='Age', y='Fare',
label='Died', color='red', kind='scatter')
ax2 = live_subset.plot(x='Age', y='Fare',
label='Survived', color='green', kind='scatter',
ax=ax1) #there is a correlation

# %%
live_subset.plot(x='Age', y='Fare',
label='Survived', color='green', kind='scatter')

# %%
df['Sex'] = pd.get_dummies(df['Sex']) # convert numerical to discrete
# make sure to reconstruct the subsets based on the Dataframe with the
# now fixed variable encoding
died_subset = df[df['Survived'] == 0]
live_subset = df[df['Survived'] != 0]

# %%
from scipy.stats import pearsonr

# %%
df['Age'].fillna(0)
# Out:
# PassengerId
# 1      22.0
# 2      38.0
# 3      26.0
# 4      35.0
# 5      35.0
# 6       0.0
# 7      54.0
# 8       2.0
# 9      27.0
# 10     14.0
# 11      4.0
# 12     58.0
# 13     20.0
# 14     39.0
# 15     14.0
# 16     55.0
# 17      2.0
# 18      0.0
# 19     31.0
# 20      0.0
# 21     35.0
# 22     34.0
# 23     15.0
# 24     28.0
# 25      8.0
# 26     38.0
# 27      0.0
# 28     19.0
# 29      0.0
# 30      0.0
#        ...
# 862    21.0
# 863    48.0
# 864     0.0
# 865    24.0
# 866    42.0
# 867    27.0
# 868    31.0
# 869     0.0
# 870     4.0
# 871    26.0
# 872    47.0
# 873    33.0
# 874    47.0
# 875    28.0
# 876    15.0
# 877    20.0
# 878    19.0
# 879     0.0
# 880    56.0
# 881    25.0
# 882    33.0
# 883    22.0
# 884    28.0
# 885    25.0
# 886    39.0
# 887    27.0
# 888    19.0
# 889     0.0
# 890    26.0
# 891    32.0
# Name: Age, dtype: float64

# %%
pearsonr(df['Age'], df['Fare']) # is this what I am supposed to get?
# Out:
# (nan, 1.0)

# %%
ax1 = died_subset.plot(x='Sex', y='Pclass',
label='Died', color='red', kind='scatter')
ax2 = live_subset.plot(x='Sex', y='Pclass',
label='Survived', color='green', kind='scatter',
ax=ax1) #sex is not an integer, therefore, error. 
# Coorect! Not more than that they are two discrete features and scatter plots only work for continuous ones19.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/lib/python3/dist-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'Sex'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-a6bebdfa0448> in <module>()
# ...

# %%
df.boxplot(column=['Fare'], by='Survived')

# %%
#a likely price to survive the Titanic might be between 25.000 and 50.000
#Real solution: With paid Fair upwards from 50, you’re an outlier if you die.
